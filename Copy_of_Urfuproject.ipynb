# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %%
sales_train=pd.read_csv('/content/drive/MyDrive/sales_train.csv')
sales_train.head(5)
# Out:
#          date  date_block_num  shop_id  item_id  item_price  item_cnt_day
# 0  02.01.2013               0       59    22154      999.00           1.0
# 1  03.01.2013               0       25     2552      899.00           1.0
# 2  05.01.2013               0       25     2552      899.00          -1.0
# 3  06.01.2013               0       25     2554     1709.05           1.0
# 4  15.01.2013               0       25     2555     1099.00           1.0

# %%
test = pd.read_csv('/content/drive/MyDrive/test.csv')
items = pd.read_csv('/content/drive/MyDrive/items.csv')
item_categories = pd.read_csv('/content/drive/MyDrive/item_categories.csv')
shops = pd.read_csv('/content/drive/MyDrive/shops.csv')
item_categories.head(5)
# Out:
#         item_category_name  item_category_id
# 0  PC - Гарнитуры/Наушники                 0
# 1         Аксессуары - PS2                 1
# 2         Аксессуары - PS3                 2
# 3         Аксессуары - PS4                 3
# 4         Аксессуары - PSP                 4

# %%
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error
from prophet import Prophet

# %%
data = pd.concat([sales_train, items, item_categories, shops], axis=1)

# %%
data = pd.merge(sales_train, items, on=['item_id'], how='left')
data = pd.merge(data, item_categories, on=['item_category_id'], how='left')
data= pd.merge(data, shops, on=['shop_id'], how='left')

# %%
print(data.head(5))
# Out:
#          date  date_block_num  shop_id  item_id  item_price  item_cnt_day  \
# 0  02.01.2013               0       59    22154      999.00           1.0
# 1  03.01.2013               0       25     2552      899.00           1.0
# 2  05.01.2013               0       25     2552      899.00          -1.0
# 3  06.01.2013               0       25     2554     1709.05           1.0
# 4  15.01.2013               0       25     2555     1099.00           1.0
#
#                                   item_name  item_category_id  \
# 0                         ЯВЛЕНИЕ 2012 (BD)                37
# 1  DEEP PURPLE  The House Of Blue Light  LP                58
# 2  DEEP PURPLE  The House Of Blue Light  LP                58
# 3  DEEP PURPLE  Who Do You Think We Are  LP                58
# 4   DEEP PURPLE 30 Very Best Of 2CD (Фирм.)                56
#
#                     item_category_name               shop_name
# 0                       Кино - Blu-Ray  Ярославль ТЦ "Альтаир"
# ...

# %%
data.to_csv('merged_dataset.csv',index=False)

# %%
# !pip install deep_translator

import pandas as pd
from deep_translator import GoogleTranslator

mergedsmall_dataset= 'path'
df = pd.read_csv('/content/mergedsmall_dataset.csv')

translator = GoogleTranslator(source='ru', target='en')

# Translate column names
df.columns = [translator.translate(col) for col in df.columns]

# Translate text data
df = df.applymap(lambda x: translator.translate(str(x)) if isinstance(x, str) else x)

# %%
print(df.head(15))
# Out:
#           date  date_block_num  shop_id  item_id  item_price  item_cnt_day  \
# 0   01/02/2013               0       59    22154      999.00             1
# 1   01/03/2013               0       25     2552      899.00             1
# 2   01/05/2013               0       25     2552      899.00            -1
# 3   01/06/2013               0       25     2554     1709.05             1
# 4   01/15/2013               0       25     2555     1099.00             1
# 5   01/10/2013               0       25     2564      349.00             1
# 6   01/02/2013               0       25     2565      549.00             1
# 7   01/04/2013               0       25     2572      239.00             1
# 8   01/11/2013               0       25     2572      299.00             1
# 9   03.01.2013               0       25     2573      299.00             3
# 10  01/03/2013               0       25     2574      399.00             2
# ...

# %%
df.to_csv('/content/drive/MyDrive/output.csv', index=False)
